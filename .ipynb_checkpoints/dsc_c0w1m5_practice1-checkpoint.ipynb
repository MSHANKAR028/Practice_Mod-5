# %% [markdown]
# # Practice for Pandas Dataframes & Series

# %% [markdown]
# 1. Load the file `WorldCupMatches.csv` as a DataFrame in pandas.

# %%
# Import pandas using the standard alias
import pandas as pd
df = pd.read_csv("WorldCupMatches.csv")

# Load 'WorldCupMatches.csv' as a DataFrame

# %% [markdown]
# 2. Use the correct method to display the first 7 rows of the dataset.

# %%
df.head(7)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# # Display the first 7 rows of df

# %% [markdown]
# 3. Display the last 3 rows of the dataset.

# %%
# Display the last 3 rows of df
df.tail(3)
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee            Assistant 1              Assistant 2  \
# 849     C�neyt �AKIR (TUR)   DURAN Bahattin (TUR)        ONGUN Tarik (TUR)
# 850  HAIMOUDI Djamel (ALG)   ACHIK Redouane (MAR)  ETCHIALI Abdelhak (ALG)
# 851   Nicola RIZZOLI (ITA)  Renato FAVERANI (ITA)     Andrea STEFANI (ITA)
#
#      RoundID    MatchID Home Team Initials Away Team Initials
# 849   255955  300186490                NED                ARG
# 850   255957  300186502                BRA                NED
# 851   255959  300186501                GER                ARG

# %% [markdown]
# 4. Get a concise summary of the data using `.info()`.

# %%
# Print a concise summary of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
#  15  Assistant 2           852 non-null    object
#  16  RoundID               852 non-null    int64
#  17  MatchID               852 non-null    int64
#  18  Home Team Initials    852 non-null    object
#  19  Away Team Initials    852 non-null    object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.3+ KB

# %% [markdown]
# 5. Obtain a tuple representing the number of rows and number of columns.

# %%
# Display the number of rows and columns in df
df.shape
# Out:
# (852, 20)

# %% [markdown]
# 6. Use the appropriate attribute to get the column names.

# %%
# Display the column names of df
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# 7. When looking at the DataFrame's `.head()` and `.tail()`, you might have noticed that the games are structured chronologically in the DataFrame.
# Use the right selection method to display all the information from the 3rd to the 5th game (i.e. select rows 3 through 5 inclusive).

# %%
# Your code here
df.iloc[3:5]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                  Referee           Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)   LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)  SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA

# %% [markdown]
# 8. Now, display the info from games labeled 5-9 in the index (inclusive), but only the "Home Team Name" and the "Away Team Name" columns.

# %%
# Your code here
df.loc[5:9, ["Home Team Name", "Away Team Name"]]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# 9. Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.
# Hint: You can combine conditions like this:
# - df[(condition1) | (condition2)] -> Returns rows where either condition is true
# - df[(condition1) & (condition2)] -> Returns rows where both conditions are true

# %%
# Display all info for games played in 1950 for Group 3
df[(df["Year"] == 1950) & (df["Stage"] == "Group 3")]
# Out:
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR

# %% [markdown]
# 10. Let's repeat the command above, but this time display only the attendance column for the Group 3 games.

# %%
# Your code here
df[(df['Year'] == 1950) & (df['Stage'] == 'Group 3')]['Attendance']
# Out:
# 56    36502.0
# 61     7903.0
# 65    25811.0
# Name: Attendance, dtype: float64

# %% [markdown]
# 11. Throughout the entire history of the World Cup as recorded in this dataset, how many home games were played by the Netherlands?
# (Remember that you can use the `len()` built-in function to find the number of rows in a DataFrame.)

# %%
# Your code here
Home = df[df["Home Team Name"] == "Netherlands"]
len(Home)
# Out:
# 32

# %% [markdown]
# 12. How many games were played by the Netherlands in total?

# %%
# Your code here
tot = df[(df['Home Team Name'] == 'Netherlands') | (df['Away Team Name'] == 'Netherlands')]
len(tot)
# Out:
# 54

# %% [markdown]
# 13. Next, let's try and figure out how many games the USA played in the 2014 World Cup.

# %%
# Your code here
USA_2014 = df[(df['Year'] == 2014) & ((df['Home Team Name'] == 'USA') | (df['Away Team Name'] == 'USA'))]
len(USA_2014)
# Out:
# 5

# %% [markdown]
# 14. The Match ID is a unique match identifer for international games:
# - set this to the index and inspect the head to verify changes.

# %%
# Your code here
df.set_index("MatchID", inplace = True)
df.head()
# Out:
#          Year              Datetime    Stage         Stadium         City  \
# MatchID
# 1096     1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1090     1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 1093     1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 1098     1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 1085     1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#         Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# MatchID
# 1096            France                4                1         Mexico
# 1090               USA                3                0        Belgium
# 1093        Yugoslavia                2                1         Brazil
# 1098           Romania                3                1           Peru
# 1085         Argentina                1                0         France
#
#         Win conditions  Attendance  Half-time Home Goals  \
# MatchID
# 1096                        4444.0                     3
# 1090                       18346.0                     2
# 1093                       24059.0                     2
# 1098                        2549.0                     1
# 1085                       23409.0                     0
#
#          Half-time Away Goals                 Referee  \
# MatchID
# 1096                        0  LOMBARDI Domingo (URU)
# 1090                        0       MACIAS Jose (ARG)
# 1093                        0     TEJADA Anibal (URU)
# 1098                        0   WARNKEN Alberto (CHI)
# 1085                        0     REGO Gilberto (BRA)
#
#                       Assistant 1                 Assistant 2  RoundID  \
# MatchID
# 1096        CRISTOPHE Henry (BEL)         REGO Gilberto (BRA)      201
# 1090     MATEUCCI Francisco (URU)       WARNKEN Alberto (CHI)      201
# 1093      VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)      201
# 1098          LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)      201
# 1085         SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)      201
#
#         Home Team Initials Away Team Initials
# MatchID
# 1096                   FRA                MEX
# 1090                   USA                BEL
# 1093                   YUG                BRA
# 1098                   ROU                PER
# 1085                   ARG                FRA

# %% [markdown]
# 15. Select data from Home Team Name to Half-time Away Goals for Match ID 1085. Use slicing here:

# %%
 # Your code here
# Slicing from Home Team Name to Half-time Away Goals
df.loc[1085, 'Home Team Name':'Half-time Away Goals']
# Out:
# Home Team Name          Argentina
# Home Team Goals                 1
# Away Team Goals                 0
# Away Team Name             France
# Win conditions
# Attendance                23409.0
# Half-time Home Goals            0
# Half-time Away Goals            0
# Name: 1085, dtype: object

# %% [markdown]
# 16. Reset the index back to integer index and move the `MatchID` back to a column in the DataFrame.

# %%
 # Your code here
df.reset_index(inplace = True)

# %% [markdown]
# 17. For your analysis, you realized that you don't need information on Referee Assistants and Win Conditions. Remove these columns and modify the original dataframe in-place. Print the column list to verify that these changes have taken place.

# %%
 # Your code here
df.drop(columns=['Assistant 1', 'Assistant 2', 'Win conditions'], inplace=True)
print(df.columns)
# Out:
# Index(['MatchID', 'Year', 'Datetime', 'Stage', 'Stadium', 'City',
#        'Home Team Name', 'Home Team Goals', 'Away Team Goals',
#        'Away Team Name', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'RoundID', 'Home Team Initials',
#        'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# 18. Check the data type of the DateTime column using the appropriate Series method.

# %%
 # Your code here
df['Datetime'].dtype
# Out:
# dtype('O')

# %% [markdown]
# 19. The dtype 'O' is the object data type. Here it is indicating that we have a column of strings. Now, convert this column to a datetime data type and make sure the changes are administered to the original dataframe df:
# - the string formatting for datetimes in this column are not all exactly the same (i.e. they are mixed)
# use the 'mixed' option for the format keyword argument in the pandas conversion function.

# %%
 # Your code here
# Using the 'mixed' format as the instructions suggested
df['Datetime'] = pd.to_datetime(df['Datetime'], format='mixed')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MatchID               852 non-null    int64
#  1   Year                  852 non-null    int64
#  2   Datetime              852 non-null    datetime64[ns]
#  3   Stage                 852 non-null    object
#  4   Stadium               852 non-null    object
#  5   City                  852 non-null    object
#  6   Home Team Name        852 non-null    object
#  7   Home Team Goals       852 non-null    int64
#  8   Away Team Goals       852 non-null    int64
#  9   Away Team Name        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  RoundID               852 non-null    int64
#  15  Home Team Initials    852 non-null    object
#  16  Away Team Initials    852 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(7), object(8)
# memory usage: 113.3+ KB

# %% [markdown]
# 20. In World Cup history, how many matches had 5 goals or more in total? First, create a new column "Total Goals".

# %%
 # Your code here
df['Total Goals'] = df['Home Team Goals'] + df['Away Team Goals']

# %% [markdown]
# 21. Filter the dataset based on the "Total Goals" column and save it to a new dataframe `high_score_df`. Then get the number of matches satisfying the above condition.

# %%
# Your code here
score = df[df['Total Goals'] >= 5]
len(score)
# Out:
# 147

# %% [markdown]
# 22. In the dataframe df, create a new column "High_Total_Score" that has value 0 if the total number of goals in a match was less than 5 and 1 if the there were 5 or more goals scored in total.

# %%
# Your code here
# Using a lambda or a simple boolean check
df['High_Total_Score'] = df['Total Goals'].apply(lambda x: 1 if x >= 5 else 0)

# %% [markdown]
# 23. Now create a new column "Half-time Goals" in df that includes both home and away values.

# %%
# Your code here
df['Half-time Goals'] = df['Half-time Home Goals'] + df['Half-time Away Goals']

# %% [markdown]
# 24. Select all records that contain matches where North-Korea (Korea DPR) and South-Korea (Korea Republic) were involved.

# %%
# Your code here
Korea_Team = ['Korea DPR', 'Korea Republic']
Korea_Match = df[(df['Home Team Name'].isin(Korea_Team)) | (df['Away Team Name'].isin(Korea_Team))]
Korea_Match
# Out:
#        MatchID  Year            Datetime           Stage  \
# 80        1294  1954 1954-06-17 18:00:00         Group 2
# 88        1304  1954 1954-06-20 17:00:00         Group 2
# 171       1710  1966 1966-07-12 19:30:00         Group 4
# 179       1609  1966 1966-07-15 19:30:00         Group 4
# 187       1679  1966 1966-07-19 19:30:00         Group 4
# 195       1702  1966 1966-07-23 15:00:00  Quarter-finals
# 364        395  1986 1986-06-02 12:00:00         Group A
# 374        460  1986 1986-06-05 16:00:00         Group A
# 386        643  1986 1986-06-10 12:00:00         Group A
# 421         57  1990 1990-06-12 17:00:00         Group E
# 434        175  1990 1990-06-17 21:00:00         Group E
# 444        290  1990 1990-06-21 17:00:00         Group E
# 464       3050  1994 1994-06-17 19:30:00         Group C
# 480       3065  1994 1994-06-23 19:30:00         Group C
# 490       3076  1994 1994-06-27 16:00:00         Group C
# 524       8732  1998 1998-06-13 17:30:00         Group E
# 542       8749  1998 1998-06-20 21:00:00         Group E
# 556       8765  1998 1998-06-25 16:00:00         Group E
# 593   43950014  2002 2002-06-04 20:30:00         Group D
# 609   43950030  2002 2002-06-10 15:30:00         Group D
# 625   43950047  2002 2002-06-14 20:30:00         Group D
# 635   43950056  2002 2002-06-18 20:30:00     Round of 16
# 639   43950059  2002 2002-06-22 15:30:00  Quarter-finals
# 640   43950061  2002 2002-06-25 20:30:00     Semi-finals
# 642   43950063  2002 2002-06-29 20:00:00     Third place
# 655   97410014  2006 2006-06-13 15:00:00         Group G
# 672   97410029  2006 2006-06-18 21:00:00         Group G
# 691   97410046  2006 2006-06-23 21:00:00         Group G
# 710  300061459  2010 2010-06-12 13:30:00         Group B
# 721  300061490  2010 2010-06-15 20:30:00         Group G
# 725  300061458  2010 2010-06-17 13:30:00         Group B
# 737  300061487  2010 2010-06-21 13:30:00         Group G
# 742  300111115  2010 2010-06-22 20:30:00         Group B
# 753  300061486  2010 2010-06-25 16:00:00         Group G
# 756  300061504  2010 2010-06-26 16:00:00     Round of 16
# 788  300186499  2014 2014-06-17 18:00:00         Group H
# 802  300186495  2014 2014-06-22 16:00:00         Group H
# 818  300186480  2014 2014-06-26 17:00:00         Group H
#
#                                Stadium                                City  \
# 80                            Hardturm                             Zurich
# 88                          Charmilles                             Geneva
# 171                      Ayresome Park                      Middlesbrough
# 179                      Ayresome Park                      Middlesbrough
# 187                      Ayresome Park                      Middlesbrough
# 195                      Goodison Park                          Liverpool
# 364     Estadio Ol�mpico Universitario                        Mexico City
# 374     Estadio Ol�mpico Universitario                        Mexico City
# 386                         Cuauhtemoc                             Puebla
# 421             Marc Antonio Bentegodi                             Verona
# 434                        Dacia Arena                              Udine
# 444                             Friuli                              Udine
# 464                        Cotton Bowl                             Dallas
# 480                    Foxboro Stadium                             Boston
# 490                        Cotton Bowl                             Dallas
# 524                   Stade de Gerland                               Lyon
# 542                    Stade V�lodrome                         Marseilles
# 556                   Parc des Princes                              Paris
# 593           Busan Asiad Main Stadium                              Busan
# 609            Daegu World Cup Stadium                              Daegu
# 625           Incheon Football Stadium                            Incheon
# 635          Daejeon World Cup Stadium                            Daejeon
# 639          Gwangju World Cup Stadium                            Gwangju
# 640            Seoul World Cup Stadium                              Seoul
# 642            Daegu World Cup Stadium                              Daegu
# 655  FIFA World Cup Stadium, Frankfurt                     Frankfurt/Main
# 672                     Zentralstadion                            Leipzig
# 691    FIFA World Cup Stadium, Hanover                            Hanover
# 710             Port Elizabeth Stadium  Nelson Mandela Bay/Port Elizabeth
# 721                 Ellis Park Stadium                       Johannesburg
# 725                Soccer City Stadium                       Johannesburg
# 737                  Cape Town Stadium                          Cape Town
# 742                     Durban Stadium                             Durban
# 753                   Mbombela Stadium                          Nelspruit
# 756             Port Elizabeth Stadium  Nelson Mandela Bay/Port Elizabeth
# 788                     Arena Pantanal                             Cuiaba
# 802                  Estadio Beira-Rio                       Porto Alegre
# 818                 Arena de Sao Paulo                          Sao Paulo
#
#      Home Team Name  Home Team Goals  Away Team Goals  Away Team Name  \
# 80          Hungary                9                0  Korea Republic
# 88           Turkey                7                0  Korea Republic
# 171    Soviet Union                3                0       Korea DPR
# 179       Korea DPR                1                1           Chile
# 187       Korea DPR                1                0           Italy
# 195        Portugal                5                3       Korea DPR
# 364       Argentina                3                1  Korea Republic
# 374  Korea Republic                1                1        Bulgaria
# 386  Korea Republic                2                3           Italy
# 421         Belgium                2                0  Korea Republic
# 434  Korea Republic                1                3           Spain
# 444  Korea Republic                0                1         Uruguay
# 464           Spain                2                2  Korea Republic
# 480  Korea Republic                0                0         Bolivia
# 490         Germany                3                2  Korea Republic
# 524  Korea Republic                1                3          Mexico
# 542     Netherlands                5                0  Korea Republic
# 556         Belgium                1                1  Korea Republic
# 593  Korea Republic                2                0          Poland
# 609  Korea Republic                1                1             USA
# 625        Portugal                0                1  Korea Republic
# 635  Korea Republic                2                1           Italy
# 639           Spain                0                0  Korea Republic
# 640         Germany                1                0  Korea Republic
# 642  Korea Republic                2                3          Turkey
# 655  Korea Republic                2                1            Togo
# 672          France                1                1  Korea Republic
# 691     Switzerland                2                0  Korea Republic
# 710  Korea Republic                2                0          Greece
# 721          Brazil                2                1       Korea DPR
# 725       Argentina                4                1  Korea Republic
# 737        Portugal                7                0       Korea DPR
# 742         Nigeria                2                2  Korea Republic
# 753       Korea DPR                0                3   C�te d'Ivoire
# 756         Uruguay                2                1  Korea Republic
# 788          Russia                1                1  Korea Republic
# 802  Korea Republic                2                4         Algeria
# 818  Korea Republic                0                1         Belgium
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 80      13000.0                     4                     0
# 88       4000.0                     4                     0
# 171     23006.0                     2                     0
# 179     13792.0                     0                     1
# 187     17829.0                     1                     0
# 195     40248.0                     2                     3
# 364     60000.0                     2                     0
# 374     45000.0                     0                     1
# 386     20000.0                     0                     1
# 421     32790.0                     0                     0
# 434     32733.0                     1                     1
# 444     29039.0                     0                     0
# 464     56247.0                     0                     0
# 480     54453.0                     0                     0
# 490     63998.0                     3                     0
# 524     39100.0                     1                     0
# 542     55000.0                     2                     0
# 556     45500.0                     1                     0
# 593     48760.0                     1                     0
# 609     60778.0                     0                     1
# 625     50239.0                     0                     0
# 635     38588.0                     0                     0
# 639     42114.0                     0                     0
# 640     65256.0                     0                     0
# 642     63483.0                     1                     3
# 655     48000.0                     0                     1
# 672     43000.0                     1                     0
# 691     43000.0                     1                     0
# 710     31513.0                     1                     0
# 721     54331.0                     0                     0
# 725     82174.0                     2                     1
# 737     63644.0                     1                     0
# 742     61874.0                     1                     1
# 753     34763.0                     0                     2
# 756     30597.0                     1                     0
# 788     37603.0                     0                     0
# 802     42732.0                     0                     3
# 818     61397.0                     0                     0
#
#                               Referee   RoundID Home Team Initials  \
# 80             VINCENTI Raymond (FRA)       211                HUN
# 88               MARINO Esteban (URU)       211                TUR
# 171            GARDEAZABAL Juan (ESP)       238                URS
# 179          KANDIL Aly Hussein (EGY)       238                PRK
# 187             SCHWINTE Pierre (FRA)       238                PRK
# 195          ASHKENAZI Menachem (ISR)       239                POR
# 364  SANCHEZ ARMINIO Victoriano (ESP)       308                ARG
# 374     AL SHANAR Fallaj Khuzam (KSA)       308                KOR
# 386                 SOCHA David (USA)       308                KOR
# 421               MAURO Vincent (USA)       322                BEL
# 434    JACOME GUERRERO Elias V. (ECU)       322                KOR
# 444               LANESE Tullio (ITA)       322                KOR
# 464             MIKKELSEN Peter (DEN)       337                ESP
# 480              MOTTRAM Leslie (SCO)       337                KOR
# 490                QUINIOU Joel (FRA)       337                GER
# 524                BENKO Gunter (AUT)      1014                KOR
# 542              WOJCIK Ryszard (POL)      1014                NED
# 556              REZENDE Marcio (BRA)      1014                BEL
# 593                  RUIZ Oscar (COL)  43950100                KOR
# 609                   MEIER Urs (SUI)  43950100                KOR
# 625               SANCHEZ Angel (ARG)  43950100                POR
# 635                MORENO Byron (ECU)  43950200                KOR
# 639           EL GHANDOUR Gamal (EGY)  43950300                ESP
# 640                   MEIER Urs (SUI)  43950400                GER
# 642                   MANE Saad (KUW)  43950500                KOR
# 655                 POLL Graham (ENG)  97410100                KOR
# 672            ARCHUNDIA Benito (MEX)  97410100                FRA
# 691            ELIZONDO Horacio (ARG)  97410100                SUI
# 710              HESTER Michael (NZL)    249722                KOR
# 721               KASSAI Viktor (HUN)    249722                BRA
# 725          DE BLEECKERE Frank (BEL)    249722                ARG
# 737                  POZO Pablo (CHI)    249722                POR
# 742        Oleg�rio BENQUEREN�A (POR)    249722                NGA
# 753    Alberto UNDIANO MALLENCO (ESP)    249722                PRK
# 756              Wolfgang STARK (GER)    249717                URU
# 788               PITANA Nestor (ARG)    255931                RUS
# 802               ROLDAN Wilmar (COL)    255931                KOR
# 818                Ben WILLIAMS (AUS)    255931                KOR
#
#     Away Team Initials  Total Goals  High_Total_Score  Half-time Goals
# 80                 KOR            9                 1                4
# 88                 KOR            7                 1                4
# 171                PRK            3                 0                2
# 179                CHI            2                 0                1
# 187                ITA            1                 0                1
# 195                PRK            8                 1                5
# 364                KOR            4                 0                2
# 374                BUL            2                 0                1
# 386                ITA            5                 1                1
# 421                KOR            2                 0                0
# 434                ESP            4                 0                2
# 444                URU            1                 0                0
# 464                KOR            4                 0                0
# 480                BOL            0                 0                0
# 490                KOR            5                 1                3
# 524                MEX            4                 0                1
# 542                KOR            5                 1                2
# 556                KOR            2                 0                1
# 593                POL            2                 0                1
# 609                USA            2                 0                1
# 625                KOR            1                 0                0
# 635                ITA            3                 0                0
# 639                KOR            0                 0                0
# 640                KOR            1                 0                0
# 642                TUR            5                 1                4
# 655                TOG            3                 0                1
# 672                KOR            2                 0                1
# 691                KOR            2                 0                1
# 710                GRE            2                 0                1
# 721                PRK            3                 0                0
# 725                KOR            5                 1                3
# 737                PRK            7                 1                1
# 742                KOR            4                 0                2
# 753                CIV            3                 0                2
# 756                KOR            3                 0                1
# 788                KOR            2                 0                0
# 802                ALG            6                 1                3
# 818                BEL            1                 0                0

# %% [markdown]
# 25. Calculate the average number of goals South Korea (Korea Republic) scored when it was the Home Team. Save this to a variable mean_home_SK.

# %%
# Your code here
South_Korea = df[df['Home Team Name'] == 'Korea Republic']
mean = South_Korea['Home Team Goals'].mean()
print(mean)
# Out:
# 1.2857142857142858

# %% [markdown]
# 26. Also estimate the average spread on this by calculating the standard deviation. Save the standard deviation to a variable std_home_SK.

# %%
# Your code here
std_SK = South_Korea['Home Team Goals'].std()
print(std_SK)
# Out:
# 0.8254203058555569

# %% [markdown]
# 27. What is the maximum number of goals that North Korea has scored when it has been away?

# %%
# Your code here
# Filtering for North Korea (DPR) as the away team
Nk_Away = df[df['Away Team Name'] == 'Korea DPR']
Max_Goal = Nk_Away['Away Team Goals'].max()
print(Max_Goal)
# Out:
# 3

# %% [markdown]
# 28. Get the average attendance, home team goals, away team goals, and total goals scored over all home games for South Korea:

# %%
# Your code 
# Calculating multiple means for the South Korea home games
stats = South_Korea[['Attendance', 'Home Team Goals', 'Away Team Goals', 'Total Goals']].mean()
print(stats)
# Out:
# Attendance         43969.714286
# Home Team Goals        1.285714
# Away Team Goals        1.571429
# Total Goals            2.857143
# dtype: float64

# %% [markdown]
# 29. Does South Korea's scoring indicate that it benefits strongly from home advantage?

# %% [markdown]
# Well when looking at ther mean which is 1.28 vs the Away team. So if they were to score more hme then the home has more average.

# %% [markdown]
# 30. Get a list of the unique teams that South Korea has played when it has been on the road.

# %%
# Your code here
# Finding unique home teams played against
sk_away = df[df['Away Team Name'] == 'Korea Republic']
unique_opponents = sk_away['Home Team Name'].unique()
print(unique_opponents)
# Out:
# ['Hungary' 'Turkey' 'Argentina' 'Belgium' 'Spain' 'Germany' 'Netherlands'
#  'Portugal' 'France' 'Switzerland' 'Nigeria' 'Uruguay' 'Russia']

# %% [markdown]
# 31. Create a Series with the teams that South Korea has played against and the number of matches against each team in the dataset -- when South Korea has been away. Save this in a variable 'away_match_teamcount'.

# %%
# Your code here
# Creating the away_match_teamcount series
away_match_teamcount = sk_away['Home Team Name'].value_counts()
print(away_match_teamcount)
